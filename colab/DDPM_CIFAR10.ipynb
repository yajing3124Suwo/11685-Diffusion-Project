# %% [markdown]
# # DDPM on CIFAR-10 (Colab)
#
# 1. **Runtime → Change runtime type → Hardware accelerator → GPU** (when you need a GPU; see [Colab FAQ](https://research.google.com/colaboratory/faq.html)).
# 2. Set `REPO_URL` to your fork or course repository.
# 3. Run cells top to bottom.

# %%
REPO_URL = "https://github.com/<org-or-user>/11685-Diffusion-Project.git"  # <-- edit

# !pip install -q ruamel.yaml tqdm

import os
if not os.path.isdir("11685-Diffusion-Project"):
    # !git clone {REPO_URL}
# %cd 11685-Diffusion-Project

os.environ["DDPM_RUNTIME"] = "colab"

# %%
# Quick sanity check
import torch
print("torch:", torch.__version__, "cuda:", torch.cuda.is_available())

# %%
# Train (CIFAR-10 downloads under ./data; checkpoints under ./experiments)
# Save checkpoints to Drive if sessions disconnect: mount Drive and set DDPM_OUTPUT_DIR.
# !python train.py --config configs/ddpm_colab.yaml --runtime colab

# %%
# Optional: mount Google Drive for persistent outputs
# from google.colab import drive
# drive.mount("/content/drive")
# import os
# os.environ["DDPM_OUTPUT_DIR"] = "/content/drive/MyDrive/ddpm_experiments"
# os.environ["DDPM_DATA_DIR"] = "/content/drive/MyDrive/ddpm_data"
